# %%
import folium
import branca.colormap as cm
map_osm = folium.Map(location=[41.5265, -70.6731], zoom_start=4.5,
                    tiles = 'Stamen Terrain')
map_osm.save('osm.html')
linear= cm.LinearColormap(['blue','green', 'yellow', 'red'],
                         vmin=3, vmax=10)
linear
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import os
import folium

# %%
import branca.colormap as cm
step = cm.StepColormap(["green", 'yellow', 'red'],
                      vmin=3, vmax=10, index=[3,4,8,10],
                      caption='step')
step
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0
# ...

# %%
linear= cm.LinearColormap(['blue','green', 'yellow', 'red'],
                         vmin=3, vmax=10)
linear
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#0000ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#0000fe;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#0001fc;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#0003f9;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#0003f8;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#0004f6;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#0005f5;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#0006f3;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#0006f2;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0007f0;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0008ef;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0
# ...

# %%
linear2 = cm.LinearColormap(['red', 'orange', 'yellow', 'green'],
                           index = [0, 0.2, 0.7, 1.0])
linear2
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ff0000;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ff0100;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ff0300;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ff0400;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ff0600;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ff0800;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ff0900;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ff0b00;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ff0d00;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ff0e00;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ff1000;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ff1200;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0002fb;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0
# ...
